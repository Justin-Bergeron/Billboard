# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# /anaconda/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/search?q=artist%3Amuse&limit=10&offset=0&type=artist
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-10-c3475521c69b> in <module>()
#       1 spotify = spotipy.Spotify()
# ...

# %%
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

pp = pprint.PrettyPrinter(indent=4)


client_credentials_manager = SpotifyClientCredentials(client_id='f9e7bf70628e48acb0ae0878c7e28189', client_secret='6dbea35c563749039101f428b08a8437')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlists = sp.user_playlists('Username')
songs = sp.track('11dFghVXANMlKmJXsNCbNl')
pp.pprint(songs)


# print(playlists)

# while playlists:
#     for i, playlist in enumerate(playlists['items']):
#         print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
#     if playlists['next']:
#         playlists = sp.next(playlists)
#     else:
#         playlists = None
# Out:
# {   'album': {   'album_type': 'single',
#                  'artists': [   {   'external_urls': {   'spotify': 'https://open.spotify.com/artist/6sFIWsNpZYqfjUpaCgueju'},
#                                     'href': 'https://api.spotify.com/v1/artists/6sFIWsNpZYqfjUpaCgueju',
#                                     'id': '6sFIWsNpZYqfjUpaCgueju',
#                                     'name': 'Carly Rae Jepsen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6sFIWsNpZYqfjUpaCgueju'}],
#                  'available_markets': [],
#                  'external_urls': {   'spotify': 'https://open.spotify.com/album/0tGPJ0bkWOUmH7MEOR77qc'},
#                  'href': 'https://api.spotify.com/v1/albums/0tGPJ0bkWOUmH7MEOR77qc',
#                  'id': '0tGPJ0bkWOUmH7MEOR77qc',
#                  'images': [   {   'height': 640,
# ...

# %%
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

pp = pprint.PrettyPrinter(indent=4)


client_credentials_manager = SpotifyClientCredentials(client_id='f9e7bf70628e48acb0ae0878c7e28189', client_secret='6dbea35c563749039101f428b08a8437')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

#playlists = sp.user_playlists('Username')
songs = sp.audio-analysis('11dFghVXANMlKmJXsNCbNl')


pp.pprint(songs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-d8c45aa44aad> in <module>()
#      10
#      11 #playlists = sp.user_playlists('Username')
# ---> 12 songs = sp.audio-analysis('11dFghVXANMlKmJXsNCbNl')
#      13
#      14
#
# AttributeError: 'Spotify' object has no attribute 'audio'

# %%
#For track
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Make your own Spotify app at https://beta.developer.spotify.com/dashboard/applications
client_id = 'f9e7bf70628e48acb0ae0878c7e28189'
client_secret = '6dbea35c563749039101f428b08a8437'
title = 'Clocks'
artist = 'Coldplay'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False
search_querry = title + ' ' + artist
result = sp.search(search_querry)
for i in result['tracks']['items']:
    # Find a songh that matches title and artist
    if (i['artists'][0]['name'] == artist) and (i['name'] == title):
        track = i['uri']
        track_name = i['name']
        #print (track)
        artist = i['artists'][0]['uri']
       # print (artist)
        break
else:
    try:
        # Just take the first song returned by the search (might be named differently)
        print (result['tracks']['items'][0]['uri'])
    except:
        # No results for artist and title
        print ("Cannot Find URI")
        

# Make your own Spotify app at https://beta.developer.spotify.com/dashboard/applications
client_id = 'f9e7bf70628e48acb0ae0878c7e28189'
client_secret = '6dbea35c563749039101f428b08a8437'


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False
artist_features = sp.artist(artist)
track_features = sp.audio_features(track)


key = ''
numkey = track_features[0]['key']
if numkey == 1:
    key = 'C#'
elif numkey == 2: 
    key = 'D'
elif numkey == 3: 
    key = 'D#'
elif numkey == 4: 
    key = 'E'    
elif numkey == 5: 
    key = 'F'
elif numkey == 6: 
    key = 'F#'    
elif numkey == 7: 
    key = 'G'    
elif numkey == 8: 
    key = 'G#'    
elif numkey == 9: 
    key = 'A'    
elif numkey == 10: 
    key = 'A#'
elif numkey == 11: 
    key = 'B'    
else: 
    key = 'C'    

numMode = track_features[0]['mode']

mode = 'Major'    
if numMode == 0: 
    mode = 'Minor'
    
durMs = track_features[0]['duration_ms']  
length = (durMs/1000)/60




print ('Artist:', artist_features['name'])
print ('Followers:', artist_features['followers']['total'])
print ('Genres:', artist_features['genres'])
print ('Popularity:', artist_features['popularity'])
print ('Track Name', i['name'])
print ('KeySig:', key + ' ' + mode)
print ('Tempo:', int(track_features[0]['tempo']))
print ('Length:', length)
print ('TimeSig:', track_features[0]['time_signature'])
print ('Danceability:', track_features[0]['danceability'])
print ('Energy:', track_features[0]['energy'])
print ('Valence:', track_features[0]['valence'])
print ('Acousticness:', track_features[0]['acousticness'])
print ('Key:', numkey)
print ('Mode:', track_features[0]['mode'])
print ('Duration(ms):', track_features[0]['duration_ms'])
# Out:
# Artist: Coldplay
# Followers: 13415614
# Genres: ['permanent wave', 'pop']
# Popularity: 84
# Track Name Clocks
# KeySig: F Minor
# Tempo: 130
# Length: 5.131333333333333
# TimeSig: 4
# Danceability: 0.577
# Energy: 0.749
# Valence: 0.261
# Acousticness: 0.599
# Key: 5
# Mode: 0
# Duration(ms): 307880

# %%
key = ''
numkey = track_features[0]['key']
if numkey == 1:
    key = 'C#'
elif numkey == 2: 
    key = 'D'
elif numkey == 3: 
    key = 'D#'
elif numkey == 4: 
    key = 'E'    
elif numkey == 5: 
    key = 'F'
elif numkey == 6: 
    key = 'F#'    
elif numkey == 7: 
    key = 'G'    
elif numkey == 8: 
    key = 'G#'    
elif numkey == 9: 
    key = 'A'    
elif numkey == 10: 
    key = 'A#'
elif numkey == 11: 
    key = 'B'    
else: 
    key = 'C'    

numMode = track_features[0]['mode']

mode = 'Major'    
if numMode == 0: 
    mode = 'Minor'
    
durMs = track_features[0]['duration_ms']  
length = (durMs/1000)/60


    
print ('Name:', artist_features['name'])

print ('Followers:', artist_features['followers']['total'])
print ('Genres:', artist_features['genres'])
print ('Popularity:', artist_features['popularity'])
print ('KeySig:', key + ' ' + mode)
print ('Tempo:', int(track_features[0]['tempo']))
print ('Length:', length)
print ('TimeSig:', track_features[0]['time_signature'])
print ('Danceability:', track_features[0]['danceability'])
print ('Energy:', track_features[0]['energy'])
print ('Valence:', track_features[0]['valence'])
print ('Acousticness:', track_features[0]['acousticness'])
print ('Key:', numkey)
print ('Mode:', track_features[0]['mode'])
print ('Duration(ms):', track_features[0]['duration_ms'])
# Out:
# <class 'float'>
# Name: Coldplay
# Followers: 13413854
# Genres: ['permanent wave', 'pop']
# Popularity: 84
# KeySig: F Minor
# Tempo: 130
# Length: 5.131333333333333
# TimeSig: 4
# Danceability: 0.577
# Energy: 0.749
# Valence: 0.261
# Acousticness: 0.599
# Key: 5
# Mode: 0
# Duration(ms): 307880

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Make your own Spotify app at https://beta.developer.spotify.com/dashboard/applications
client_id = 'f9e7bf70628e48acb0ae0878c7e28189'
client_secret = '6dbea35c563749039101f428b08a8437'
track = 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False
track_features = sp.audio_features(track)
print(features)
print ('Key:', track_features[0]['key'])
print ('Mode:', track_features[0]['mode'])
print ('Tempo:', track_features[0]['tempo'])
print ('Duration:', track_features[0]['duration_ms'])
print ('TimeSig:', track_features[0]['time_signature'])
print ('Danceability:', track_features[0]['danceability'])
print ('Energy:', track_features[0]['energy'])
print ('Valence:', track_features[0]['valence'])
print ('Acousticness:', track_features[0]['acousticness'])
# Out:
# [{'danceability': 0.577, 'energy': 0.749, 'key': 5, 'loudness': -7.215, 'mode': 0, 'speechiness': 0.0279, 'acousticness': 0.599, 'instrumentalness': 0.0112, 'liveness': 0.183, 'valence': 0.261, 'tempo': 130.969, 'type': 'audio_features', 'id': '0BCPKOYdS2jbQ8iyB56Zns', 'uri': 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns', 'track_href': 'https://api.spotify.com/v1/tracks/0BCPKOYdS2jbQ8iyB56Zns', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BCPKOYdS2jbQ8iyB56Zns', 'duration_ms': 307880, 'time_signature': 4}]
# Key: 5
# Mode: 0
# Tempo: 130.969
# Duration: 307880
# TimeSig: 4
# Danceability: 0.577
# Energy: 0.749
# Valence: 0.261
# Acousticness: 0.599

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Make your own Spotify app at https://beta.developer.spotify.com/dashboard/applications
client_id = 'f9e7bf70628e48acb0ae0878c7e28189'
client_secret = '6dbea35c563749039101f428b08a8437'
artist = 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'
      #'spotify:track:0BCPKOYdS2jbQ8iyB56Zns'


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False
features = sp.artist(uri)
print ('Name:', features['name'])
print ('Followers:', features['followers']['total'])
print ('Genres:', features['genres'])
print ('Popularity:', features['popularity'])
# Out:
# Name: Coldplay
# Followers: 13413061
# Genres: ['permanent wave', 'pop']
# Popularity: 84
